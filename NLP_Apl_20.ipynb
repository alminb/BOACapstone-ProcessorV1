# %%
import os
import pandas as pd
from datetime import date
start_day = date.today()
end_date = start_day
print(end_date)
search_term = '#bankofamerica'
from_date = '2021-12-01'
os.system(f"snscrape --since {from_date} twitter-search '{search_term} until:{end_date}' > result-tweets.txt")
if os.stat("result-tweets.txt").st_size == 0:
          counter = 0
else: 
          df = pd.read_csv('result-tweets.txt', names=['link'])
          counter = df.size
          
print('Number of Tweets : ' + str(counter))
# Out:
# 2022-04-20
# Number of Tweets : 2714

# %%
max_results = 5000
extracted_tweets = "snscrape --format '{content!r}'"+ f" --max-results {max_results} --since {from_date} twitter-search '{search_term} until:{end_date}' > extracted-tweets.txt"
os.system(extracted_tweets)
if os.stat("extracted-tweets.txt").st_size == 0:
    print("No tweets found")
else: 
    df = pd.read_csv('extracted-tweets.txt', names=['content'])
    for row in df['content'].iteritems():
        print(row)
# Out:
# (("'Dear @BankofAmerica", '\\nWhy do you indiscriminately ((temporarily)) close branches'), " without notice to customers and no notice as to when they’ll reopen?\\nVery inconvenient😡\\n#bankofamerica'")
# (("'2022-04-19 5:40 PM\\n$BAC #BankofAmerica up 1.85% = $6.07 billion gain.\\n\\nhttps://t.co/Gi0bAJJ5Ik\\n(Apr 18) Bank of America Corp. stock outperforms competitors on strong trading day https://t.co/IfMkGjji8f'", nan), nan)
# (("'Bank of America still sees gold price hitting record highs and silver price pushing to $30\\n\\n#Gold #GoldMine #StockMarketNews #Bullish #Gains #BankofAmerica #Analysts $LORD $LORD.V $LRDJF $NFG.V $NFG $NFGFF $TPRFF $JAG $JAG.V $PAAS $RGLD $AEM $GLL\\n\\nhttps://t.co/e6XxRV28Lz'", nan), nan)
# (("'Looking for ways to increase employee engagement for your team or business? Read this interview with ISEA award-winning Academy at @BankofAmerica\\n  ! 💻 ✨🏆\\n\\nClick here https://t.co/PCgmoDaUQA\\n\\n#employeeengagement #virtualreality  #bankofamerica  #redefiningserviceexcellence https://t.co/dF2k5YGDJl'", nan), nan)
# (("'“Iron Mike” Tyson &amp; Bank of America (BoA) Back Solana (SOL) | by Stephen Dalton | B.O.S.S. |Medium - via @pensignal  https://t.co/ZW7zoWUPRw $SOL #Solana #BankofAmerica #MikeTyson @MikeTyson #cryptocurrencies  #writingservices #writerscommunity #medium #writerslift #SEO #Blogging'", nan), nan)
# (("'#Options Flow Grid Update $BAC #OptionsTrading #bankofamerica Shares ⬆️1.85% to $39.56 #OptionsFlow #BoA #financialservices #Financial #stocks #stock #StockMarket #investing #Investment https://t.co/B7BWRcVOEf https://t.co/NzftFnEwHm'", nan), nan)
# (("'BofA settles maternity leave discrimination case for $15K https://t.co/4ZkHDeIq8o #CFPBRegulatory #Enforcement #Mortgage #BankofAmerica'", nan), nan)
# (("'Bank of America gana 7.100 millones en el primer trimestre (-12%) y supera previsiones https://t.co/gl3pHJzzQv via @Bolsamania \\n #BANKOFAMERICA #BOA #BAC $BAC #Nyse 🇺🇸\\n #banco #banca #inversion 🏦🧑\\u200d💼💰\\n  Más sobre Bank of America en https://t.co/36cb1kC99y'", nan), nan)
# (("'Angst vor der #Rezession macht plötzlich Lust auf #Bitcoin \\n#bankofamerica \\nhttps://t.co/0C9m3Vj7iw'", nan), nan)
# (("'During the first quarter", " @BankofAmerica revenue increased by 2% to $23.23 billion from $22.8 billion a year earlier supported by the strong growth in its consumer lending business. 🏦🇺🇸\\n\\nRead more ⬇️\\nhttps://t.co/3w7Jwoc2Pl\\n\\n#bankofamerica #stock #wallstreet #gulfbrokers #review https://t.co/FbVfVVwVlS'"), nan)
# (("'«Deal-Pause bei US-Banken» (Abo) \\nvon Monica Hegglin (https://t.co/X96cMvxTyv) \\n#bankofamerica #citigroup #creditsuisse #goldmansachs #morganstanley #ubs'", nan), nan)
# (("#US: Market Update\\n- #BankOfAmerica fuels S&amp;P500 higher post earnings\\n- #DIDI to meet on #US delisting plans\\n- #Twitter sinks after adopting 'poison pill', shares fall 2%\\nSource: Reuters", nan), nan)
# (("'📎Por su alta proporción de banca para individuos", ' #BankofAmerica lleva ventaja para beneficiarse de un entorno de tasas más altas.\\n📌Cotiza a un P/B ratio de x1'), '12')
# (("$BAC's Aroon indicator drops into Downtrend on March 17, 2022. View odds for this and other indicators: https://t.co/WVGUrmWf87 #BankofAmerica #stockmarket #stock https://t.co/gCRgyPVj9k", nan), nan)
# (("Deleted previous post. Later I went to confront the man who verbally attacked me. I asked him if he is the new super and why his aggressiveness. He didn't confirm me and said I'm better than him and I've lived in the building since 1984.#bankofamerica https://t.co/Xjw3EX5hc9", nan), nan)
# (("'https://t.co/k8rOIRb4hm\\n#BOFA #bankofamerica #stock'", nan), nan)
# (("'Bank of America straalt op de beurs van Wall Street\\nhttps://t.co/RphvVCpWne | #bankofamerica https://t.co/8BajWRGfuw'", nan), nan)
# (("'Ive been an account holder for years. It’s very rare I overdraft &amp; if I do it’s a life changing situation happening. I called and spoke to a wonderful rep today who tried to reverse the fee but it was denied by the supervisor. I’m hurt @BankofAmerica #bankofamerica #banks #fees'", nan), nan)
# (("'It’s disappointing when banks take advantage of their account holders with overdraft fees. I transferred money into my @BankofAmerica account to prevent an overdraft. The money hit my account today but they still hit me with overdraft fees today #overdraft #bankofamerica'", nan), nan)
# (("'S&amp;P 500 futures slip as rates reach a recent 3-year high", " investors evaluate a big week of earnings\\nhttps://t.co/azQXcNubuq #Stock #DowJonesIndustrial #Nasdaqfutures #FederalReserve #BankofAmerica #premarket #Verizon #AmericanExpress #JohnsonandJohnson @THEWOMENLEADERS'"), nan)
# (("'Let’s look at the top #stocks gainers.\\n\\n#twitter +5.1%", ' #EQT +4.63%'), ' #bankofamerica +4.05%')
# (("'Bank of America profit tops estimated as lender releases reserves for soured loans\\nhttps://t.co/unlQ8CgvFr #bank #BankofAmerica #premarket #Shares #payments #StreetAccount #AlastairBorthwick #Growth #JPMorganChase #BrianMoynihan @THECORPMAGAZINE'", nan), nan)
# (("'#BankofAmerica shares jump after earnings.\\n\\n#stocks #stockmarket #banks #nifty  https://t.co/ZEm9nzg8Uc'", nan), nan)
# (("'Bank of America $BAC reported yesterday. A thread on the results and implications.\\n\\n#BankofAmerica'", nan), nan)
# (("'Ains", ' que me dejaba el último!!!\\n\\n🏦#BankOfAmerica\\n👍#BPA 0'), '8 🆚0')
# (("'Börse To Go: E.ON warnt vor höheren Preisen", " #Volkswagen startet Produktion in China und Bank of America schneidet besser als befürchtet ab\\nhttps://t.co/INEKVS3GU7\\n\\n#EON #BankofAmerica #Aktie #Wirtschaft #DAX #WallStreet #NTG24'"), nan)
# (("'Wall St ends lower as investors await further earnings cues #fintwit #bankofamerica #jackjanasiewicz #tesla #marketparticipants #tslao #jnjn https://t.co/zkCu8un6T8'", nan), nan)
# (("'$BAC enters bearish trend #BankofAmerica #stockmarket #stock https://t.co/BZ33LoZ9a8'", nan), nan)
# (("'#opendir #phishing #bankofamerica #zip\\n\\nhxxps://wp.asrofashion[.]com/bo/bd/\\n\\n@SteveD3 @JCyberSec_ https://t.co/tEjq2VnAUj'", nan), nan)
# (("'Banking On Bank Of America https://t.co/YYqTOF2zWe #bankofamerica #NYSEBAC'", nan), nan)
# (("'🌐#globalmarket मिलेजुले \\nUS बाजार लगातार तीसरे दिन फिसले🔻\\nसीमित दायरे में कारोबार के बीच #DowJones 40 अंक नीचे\\n#SNP500 #NASDAQ पर हल्की गिरावट  \\n\\nअच्छे नतीजों से #BankOfAmerica 3% ऊपर🔼\\n#Twitter शेयर 7% उछला\\n📉यूरोप में 0.5% तेजी\\n#Brent $113 के करीब \\n\\n@deepdbhandari @Neha_1007 https://t.co/zZNtYK7HZj'", nan), nan)
# (("'Bank of America Q1 results: CFO sees continued strength ahead. \\n#BankOfAmerica #Q1EarningsReport #BAC #StockMarketNews #AlastairBorthwick #WallStreetBank #NYSE\\nhttps://t.co/IdIFfKkDg8 https://t.co/4S7oi4uCgr'", nan), nan)
# (("'I don\\'t know who needs to hear this", ' but: Dear #PayPal'), ' #CapitolOne')
# (("#BankOfAmerica do we need to set up travel dates to go to Mexico?? I called 3 freaking times and I can't get thru", nan), nan)
# (("'Stock Talk With CK: Bank of American Corporation ($BAC) Earnings (Q1 F... https://t.co/AfKsU9zOVy \\n#BankofAmerica #BAC $BAC #Bank #BankingNews #banking #finance #Financial #StockMarket #stocks #stockstowatch #earnings #service #loans https://t.co/DsrE0jQnuI'", nan), nan)
# (("'#BankofAmerica supera estimativas de lucro com força em crédito ao consumo - https://t.co/HnEGpnMGmm \\n\\n$BAC #BOAC34'", nan), nan)
# (("'#Mercado Bank of America obtiene beneficio de 7.067 millones de dólares en 2022\\n\\n#BankofAmerica #EstadosUnidos #Ingresos #Depósito https://t.co/gp4xkaJK2j'", nan), nan)
# (("'The bank reported a 9% rise in consumer banking revenue to $8.8 billion in the quarter ended March\\n\\n#BankofAmerica\\nDownload the all-new BS App here - https://t.co/DAH4tItnej\\nhttps://t.co/MyOrUrVxfb'", nan), nan)
# (("'Bank of America Tops Analyst’s First-Quarter Estimates\\n\\n$BAC #BankofAmerica #Coronavirus #COVID19 #Earnings #FederalReserve #FinancialInstitution #FinancialResults #FirstQuarter #Pandemic #Shares https://t.co/sIzInYpNJH'", nan), nan)
# (("'Global #growth optimism hits all-time low – research\\nConcerns about possible stagflation are at their highest since 2008", " says the #BankofAmerica https://t.co/6FQ6WAdwMc'"), nan)
# (("'Bank of America (BAC) beats earnings estimate; stocks gain.\\nhttps://t.co/LKXGpwsfAk\\n#BAC #BankofAmerica #BACearnings #earningsbeat #earnings #premarket $BAC'", nan), nan)
# (("'$BAC  8-K  Bank Of America   (18 Apr", " 6:47am)\\n\\n📰 Results of Operations and Financial Condition; Regulation FD Disclosure\\n\\nhttps://t.co/RiclG2smVA\\n\\n#BAC #8K #BankOfAmerica #News'"), nan)
# (("'🇺🇸 𝗨𝗦 𝗲𝗮𝗿𝗻𝗶𝗻𝗴𝘀 𝘀𝗲𝗮𝘀𝗼𝗻 | Bank of America $BAC will report its latest financial results for Q1 today.\\n\\nHere is what the expectations are ahead of the earnings call 👇🏻\\n\\nEPS: $0.75\\nRevenue: $23.131b\\n\\n#BankofAmerica #BAC #Earnings #Stocks #WallStreet #NYSE https://t.co/8EhPGb1HeJ'", nan), nan)
# (("'Intraday Technical Analysis on Bank of America Corp. \\n\\nRead More  👉 https://t.co/hb0KeZCfWg\\n\\n#AAATrade #forex #stocks #financialnews #forexnews  #stockmarket #BankofAmerica #BAC https://t.co/AZhSKEJNzB'", nan), nan)
# (("#Earnings come this week from #BankofAmerica, #CharlesSchwab, #BNYMellon, #Synchrony, #AmEx, #Netflix, #IBM, #Travelers, #Tesla and #Verizon. We've also got eurozone #CPI, US existing home sales and UK #retail sales. Full #WeekAhead at https://t.co/FHc2eDdams https://t.co/cWls1kiQtr", nan), nan)
# (("'Among others", ' #BankofAmerica pledged over $1billion to BLM. (What interest are you paying on their credit cards?) Besides the mansions'), " perhaps #BLM can spend some of the $ on lessons in manners. https://t.co/Uisb8DhpZU'")
# (("'#BabyDogeCoin  #BabyDogeArmy #CryptoNews #cryptocurrecy #WallStreet #jpmorganchase #morganstanley #bankofamerica https://t.co/5P6kpUFd2N'", nan), nan)
# (("'“Iron Mike” Tyson &amp; Bank of America (BoA) Back Solana (SOL) | by Stephen Dalton | B.O.S.S. |Medium - via @pensignal  https://t.co/bWMmwnimmr $SOL #Solana #BankofAmerica #MikeTyson @MikeTyson #cryptocurrencies  #writingservices #writerscommunity #medium #writerslift #SEO #Blogging'", nan), nan)
# (("'“Iron Mike” Tyson &amp; Bank of America (BoA) Back Solana (SOL) | by Stephen Dalton | B.O.S.S. |Medium - via @pensignal  https://t.co/ZeXPvxq2LO $SOL #Solana #BankofAmerica #MikeTyson @MikeTyson #cryptocurrencies  #writingservices #writerscommunity #medium #writerslift #SEO #Blogging'", nan), nan)
# (("$BAC's Aroon indicator drops into Downtrend on March 17, 2022. View odds for this and other indicators: https://t.co/LYdJHwGh8W #BankofAmerica #stockmarket #stock https://t.co/J6lIzKbWdv", nan), nan)
# (("'Bank of America Corp to report earnings on April 18", " 2022. Earnings per share (EPS) estimate: $0.75 $BAC #BankofAmerica #stockmarket #stock https://t.co/XI3BdTn4qX https://t.co/y9Am7MttLt'"), nan)
# (("'Fears of recession are everywhere #bidenomics #recession #goldmansachs #supplychains #thefed #bankofamerica https://t.co/qYDpVkmWk6'", nan), nan)
# (('\'#Svengoolie #GhostOfFrankenstein "She was stoned!" Remember', " this is a old film; THC ain\\'t involved. #Kerwyn #SvenPals #FanArtworkAndPhotos #SvenPalInCarhenge #HitTheTheme4UsCreedo #ThankU4AllTheCardsAndLetters #brought2uby #BankOfAmerica &amp; #AceHardware'"), nan)
# (("'“Iron Mike” Tyson &amp; Bank of America (BoA) Back Solana (SOL) | by Stephen Dalton | B.O.S.S. |Medium - via @pensignal  https://t.co/iKt8qTXlXB $SOL #Solana #BankofAmerica #MikeTyson @MikeTyson #cryptocurrencies  #writingservices #writerscommunity #medium #writerslift #SEO #Blogging'", nan), nan)
# (("'Cómo te explicas que el capital de mercado de #btc hoy día vale más que #BankOfAmerica y #JPMorgan y la mayoría de la sociedad no hable de éso? Brutal...! #16Abril2022'", nan), nan)
# (("'Wall Street Breakfast: What Moved Markets https://t.co/HDsWM6p4Kx #Amazon #Tesla #Twitter #BankofAmerica #JPMorgan #GoldmanSachs #MorganStanley #ElonMusk #Apple #Microsoft #Sony #NVIDIA'", nan), nan)
# (("'#bankofamerica computers are down nationwide. #putin ? #Ukraine️ #Russia'", nan), nan)
# (("'@ExcessMidnight @DeKition @DufelayS @GardienDuVivant 👉 via @mk_polis💡\\n\\nCes scènes orgiaques sous masques sur fond de rituel satanique de #EWS et #9thgate 🏰 ressemblent à ce que #HenriClausen décrit\\n\\nhttps://t.co/FKCtNxDN4b\\n\\nSan Francisco #BohemianGrove\\n\\n#BankofItaly-&gt; #BankofAmerica Visa™️💳💸#APGiannini\\n\\nhttps://t.co/UYblxUmhqG https://t.co/hCCzyqFhvd'", nan), nan)
# (("'@BankofAmerica screwed me over 2day. I’m in the middle of a cross country drive to MOVE from WA to SC", " ur auto pmnt system failed &amp; u close my account &amp; refuse to allow me to dispute? Was to close on a home in 2 wks. Might not be anymore. Thanks #BoA #bankofamerica'"), nan)
# (("'Mark Baum was right in 2008 and the market is about to collapse again. #MarketCrash #Fraud #Corrupt #Jpmorgan #BankofAmerica'", nan), nan)
# (("'@Ryan06974467 My guess", ' based on my personal TA of a weekly chart'), ' is that $BAC will find support between 37.57 and 35.82. It is goes passed that last number')
# (("'@jenya_panov Не", " просто устал на это смотреть. теперь смотрю на свои отечественные минуса и минус #intel с #BankofAmerica'"), nan)
# (("'Did you know that Farquaad is trained in ballet", ' flamenco'), ' and jazz? See how he measures up in "Shrek the Musical" starting today at 2 PM. Get tix: https://t.co/W1JSG5bmRu. \\n\\n#ShrektheMusical #Shrek #ChildrensTheatre #BankofAmerica #InfusionFund #Farquaad https://t.co/kJYLv5tz4O\'')
# (("'Bank of America https://t.co/lC8AxPALRz #BankofAmerica'", nan), nan)
# (("$BAC's Aroon indicator drops into Downtrend on March 17, 2022. View odds for this and other indicators: https://t.co/4zB44rdyc3 #BankofAmerica #stockmarket #stock https://t.co/hhVwcWgwsJ", nan), nan)
# (("'#BankOfAmerica çok bastırıyor aşağıı vermek için\\n2", '89 altı kapanış ile stop olurum'), ' günlük rakamım 2')
# (("'$BAC enters bearish trend #BankofAmerica #stockmarket #stock https://t.co/2kd0W0Z65J'", nan), nan)
# (("'#bankofamerica için neler de denmiş..acaba https://t.co/Aa8inD9LFj'", nan), nan)
# (('\'Who\\\'s ready to wave their freak flags high?! Get your tickets to "Shrek the Musical" today by visiting https://t.co/W1JSG5bmRu.\\n\\n#ShrektheMusical #Shrek #ChildrensTheatre #BankofAmerica #InfusionFund https://t.co/LLCUGDOY6e\'', nan), nan)
# (("'BOA doesn’t allow you to overdraft at the ATM anymore starting Feb 2022. I’ve been a customer for 15+ yrs. This was one of the main reasons I liked them so much. Borrow $ when times tight. Thinking of switching banks &amp; I know I’m not the only one. #BankOfAmerica'", nan), nan)
# (("$BAC(-3%) dips to new '22 lows, working on 13th loss over last 14 sessions, 50/200D bear cross overhead, now 27% off '22 peak, overhead pressure intense ahead of earnings(4/18/AM), $36.50-$35.50=nearby support, #bankofamerica Bank of America #banking #fin…https://t.co/K2s7pofh9P", nan), nan)
# (("'@FloridaGoldRea1 #Boycot #BankofAmerica #AMC #GME'", nan), nan)
# (("'It has been about 18 months that I lost access to my account - in the midst of the Pandemic - and I could not regain access to it because the BOA System and\\xa0clearance procedure it is not fully digitalised! #bankofamerica'", nan), nan)
# (("'🏦 #BankOfAmerica: Vista previa del 1° Trimestre | ¿Qué sigue para las acciones de $BAC? 📈\\n\\nLa entidad informará las ganancias el lunes 18 de abril 💸 Ingresa a nuestro análisis 👇     \\n\\n📲 https://t.co/59ZuebiczQ\\n\\n#earnings #trading #banking #daytrader #stockstrading https://t.co/PsV596enwx'", nan), nan)
# (("'NY caregiver working under deafening music and pot smoke https://t.co/1IAmqh9FRK via @YouTube #bankofamerica https://t.co/IWQOWkWh3v'", nan), nan)
# (("'Does anyone actually believe all the money we have sent to Ukraine is actually going towards defense? \\n\\n#BankofAmerica #Ukraine  #Someonesgettinpaidson'", nan), nan)
# (("'“Iron Mike” Tyson &amp; Bank of America (BoA) Back Solana (SOL) | by Stephen Dalton | B.O.S.S. |Medium - via @pensignal  https://t.co/PNhTQpQbdj $SOL #Solana #BankofAmerica #MikeTyson @MikeTyson #cryptocurrencies  #writingservices #writerscommunity #medium #writerslift #SEO #Blogging'", nan), nan)
# (("'$BAC enters bearish trend #BankofAmerica #stockmarket #stock https://t.co/0Cr8U7DrXc'", nan), nan)
# (("'#Bankofamerica may the worst bank to have'", nan), nan)
# (("'@BankofAmerica what’s wrong with Zelle?  I sent my son", " who is away at school and he has not received the money! #zelle #bankofamerica'"), nan)
# (("'@BankofAmerica Why do you force customers to make some transactions in person", ' DURING A PANDEMIC'), " when they can be done by phone? We’ll move a lot of money out of #BankOfAmerica if you don’t fix this. Very upset.'")
# (("'Bank of America https://t.co/sh301KwdeO #BankofAmerica'", nan), nan)
# (("'“Iron Mike” Tyson &amp; Bank of America (BoA) Back Solana (SOL) | by Stephen Dalton | B.O.S.S. |Medium - via @pensignal  https://t.co/ZVCD8T1cT9 $SOL #Solana #BankofAmerica #MikeTyson @MikeTyson #cryptocurrencies  #writingservices #writerscommunity #medium #writerslift #SEO #Blogging'", nan), nan)
# (("'$BAC  DEFA14A  Bank Of America   (13 Apr", " 5:21pm)\\n\\n📄 Additional proxy soliciting materials\\n\\nhttps://t.co/qQrglO3xdw\\n\\n#BAC #DEFA14A #BankOfAmerica #Proxy'"), nan)
# (("'So just received a scanner call about credit card debt", ' and w/out confirming info found some other info. Who is Cassandra Reed that has my address &amp; phone #'), " with a Visa card debt to Bank of America?#scammerinfodump #bankofamerica https://t.co/y83PFc99tG'")
# (("#BankofAmerica can't keep its own branches up and running, why should I listen to them about a recession.\\n\\nCNN: 'Recession shock' is coming, Bank of America warns.\\nhttps://t.co/nyGwTqA5YU\\n\\nvia @GoogleNews", nan), nan)
# (('\'"The\\xa0Bank of America Institute for Women’s Entrepreneurship\\xa0at Cornell University is working to capitalize on this impressive growth and to support women entrepreneurs. "\\n#womenentrepreneurs #womenofcolor #bankofamerica #cornelluniversity https://t.co/TjZdq5p8Yb\'', nan), nan)
# (("$BAC's Aroon indicator drops into Downtrend on March 17, 2022. View odds for this and other indicators: https://t.co/ovDGuvY9bx #BankofAmerica #stockmarket #stock https://t.co/pmTeHcWagc", nan), nan)
# (("'@BankofAmerica @BofA_Help this door is not closing properly. South Orange Ave", " South Orange NJ.#bankofamerica #southorangenj'"), nan)
# (("'What do you think of this? $BAC RSI Indicator left the oversold zone. #BankofAmerica #stockmarket #stock https://t.co/1ngpAzoDF3 https://t.co/Awn9k5MN23'", nan), nan)
# (("A #RecessionShock is on its way and the #InflationShock is worsening says #BankofAmerica Read this week's #GlintSoapbox below, or download the #GlintApp for all our stories. \\n\\n#GlintPay #Gold #GoldCurrency #GoldStandard #GlintGold #AllocatedGold #Ukraine\\n\\nhttps://t.co/6q96bU3WVN", nan), nan)
# (("'@myselfeknath 👉#BankOfAmerica👈\\nIs that bank of #NorthAmerica or #SouthAmerica? Central?\\n\\nIf North America", ' is it including Canada and Mexico'), " or just going full on #Merica?\\n\\n-#DogeCoin of #World https://t.co/wPIdkomTof'")
# (("'Just sent $111", '000 worth of #BTC'), ' only cost $1.51\\nGet with it #ETH')
# (("'“Iron Mike” Tyson &amp; Bank of America (BoA) Back Solana (SOL) | by Stephen Dalton | B.O.S.S. |Medium - via @pensignal  https://t.co/3aUGzyOAB1 $SOL #Solana #BankofAmerica #MikeTyson @MikeTyson #cryptocurrencies  #writingservices #writerscommunity #medium #writerslift #SEO #Blogging'", nan), nan)
# (("'EXPANDING WAR: With Both Goldman Sachs And Bank of America WARNING On Th... https://t.co/1Lnxwj624e via @YouTube #America #GoldmanSachs #bankofamerica'", nan), nan)
# (("'RT jaybirdcom: RT @NYTechAlliance: Have you taken the right steps to keep your business secure? Join us - in partnership w/ #BankofAmerica", ' our next event will walk you through the latest trends in cyber security &amp; best practices. \\nWhen: Thursday'), " April … https://t.co/Bp77yIbcnC'")
# (("'I’m so pissed  that navy  FEDERAL IS NOW PROCESSING transactions like the theiving Ass @WellsFargo and #BankofAmerica  leaving and going to keep my shit myself'", nan), nan)
# (("'Bank of America: Recession will be here within a year - #investing #trading #BankofAmerica $BAC $SPY $QQQ $DJI $USD https://t.co/qvS7L2bFvu'", nan), nan)
# (("'Kicking off Global Service Month cleaning our NJ beaches. Thank you @CleanOcean and state sponsor @BofA_News. I’m so proud of our company’s continued focus on our communities and the impact we can all make. #communityevent #boavolunteer #givebacktothecommunity #bankofamerica https://t.co/GMlA33m7ti'", nan), nan)
# (("The S&amp;P 500 will plunge 11% by the end of 2022 as 'inflation shock' sparks a recession, Bank of America says #recessions #samp #investorsan #bankofamerica #recession #hawkishfed https://t.co/bYu4VTUSO3", nan), nan)
# (("'Stock market outlook: S&amp;P 500 to fall 11% as inflation sparks recession #hawkishfed #bankofamerica #recessions #recession https://t.co/5wJtl6a9aK'", nan), nan)
# (("'While the #global #economy continues to hand on a thin line", " individuals believe that #crypto might overtake #stocks in the next few months. \\n\\n#BankofAmerica #Cryptoadoption #Cryptoboom #CryptovsStocks #stockmarket\\n\\nhttps://t.co/6xjR4FhvSv'"), nan)
# (("Bank of America Strategist Warns 'Recession Shock' Is Coming, Analyst Says Crypto Could Outperform Bonds \\n\\n#bankofamerica https://t.co/jsWZROhKpL", nan), nan)
# (("'Exactly #BankofAmerica\\nSomebody finally gets it.  When inflation is soaring", ' u don’t hoard dollars (the fckin thing that’s inflating) or bonds that give 1% APY'), " you buy risky assets that (hopefully/likely) can outperform the 8% inflation.\\nElse ur losing $\\n https://t.co/BpNriDD4aU'")
# (("'Bank of America https://t.co/lQRKnZUCY5 #BankofAmerica'", nan), nan)
# (("'This was bullshit . They did not try to help me just distract me from tweeting and informing people to not bank with Bank of America . #dontbankwithbankofamerica #worstbankeverbankofamerica #bankofamerica #cantstopwontstop https://t.co/TOrH7oUWi1'", nan), nan)
# (("'அமெரிக்காவை மிரட்டும் ரெசிஷன்.. பேங்க் ஆஃப் அமெரிக்கா எச்சரிக்கை..!  #recession #russia #bankofamerica #america #economy https://t.co/OvdHzNzVAe'", nan), nan)
# (("'#PlaneAlert ICAO: #A89442 Tail: #N652BA Flt: #EJM652 \\nOwner: #BankofAmerica\\nAircraft: #Gulfstream G650 ER\\n2022/04/10 09:31:32\\n#GLF6 #Aaaaaaaanditsgone #BunchofBankers #ScroogeMcDuck https://t.co/cUszuYpU7l \\nhttps://t.co/r1uPjwlCv1'", nan), nan)
# (('\'"@solana could become the @Visa of digital-asset world" - @BankofAmerica.\\n\\n#BankOfAmerica #Crypto #Solana #Visa #crypto #USA\'', nan), nan)
# (("Bank of America predicts a'recession shock,' and believes #bitcoin will outperform markets.\\n\\n#stocks #stockmarket #bankofamerica #bank #finance https://t.co/R05LMykUZ7", nan), nan)
# (('\'Bank of America announces "recession shock"\\nhttps://t.co/L7dfscb1Kf \\n#Bitcoin\\n#BankOfAmerica\\n#recession \\n#USA \\n#bank #money\'', nan), nan)
# (("'Gambaran ekonomi makro memburuk dengan cepat dan dapat mendorong ekonomi AS ke dalam resesi karena The Fed memperketat kebijakan moneternya untuk menjinakkan lonjakan inflasi", " \\n\\nhttps://t.co/NMU3dgT98H\\n\\n#BankofAmerica #resesi #kripto #saham #AS #Bitcoin #BTC'"), nan)
# (("'Ngân hàng Trung ương Hoa Kỳ (Bank of America) cảnh báo rằng các hành động gần đây của Fed có thể dẫn đến suy thoái kinh tế", " nhưng tiền điện tử có thể trở th...\\n#BankofAmerica #GoldmanSachs #bitcoin #Citigroup #Crypto #Fed #JPMorg...\\nhttps://t.co/Lqjg4Y36kH'"), nan)
# (("'Bank of America: Crypto Can Outperform Stocks Amid Potential Fed-Propelled Recession https://t.co/mBLxevOIPh  #BankOfAmerica #FederalReserve #FED 👇👇'", nan), nan)
# (("'Did you know?\\n\\n#Ethereum surpasses #Bankofamerica", " #Mastercard in market capitalization?\\n\\n#Saitama #Impactxp #LuckyRooToken #SaitaRealty'"), nan)
# (("'#bankofamerica https://t.co/LyMApE47BZ'", nan), nan)
# (("'Recession shock coming:\\n#BankOfAmerica warns #Recessionshock is coming", " says #Crypto could outperform #Stocks.\\n\\n#Saitama #Impactxp #LuckyRooToken #SaitaRealty'"), nan)
# (("'Jobs In #Crypto \\n\\n#Facebook", ' #Microsoft'), ' #Apple')
# (("'USA RECKLESS SPENDING - LIKE THERE IS NO TOMORROW\\nThe #macroeconomic picture is deteriorating rapidly and could push the #USeconomy into #recession as the Federal Reserve tightens monetary policy to tame surging #inflation", " #BankofAmerica (#BofA) warned on Friday. https://t.co/9coIjs7hyL'"), nan)
# (("#BankofAmerica: #Crypto Can Outperform Stocks Amid Potential Fed-Propelled Recession 🚀🚀🚀(We know that but it's time for you to admit it) . \\n#CryptoNews #cryptotrading #NFT #Metaverse #blockchain #Web3 https://t.co/yYXh3V0SSY", nan), nan)
# (("'摩根大通\\n美国银行\\n花旗银行\\n富国银行\\n高盛\\n摩根士丹利\\n全美银行\\n\\n如果说下半年需要洗掉一家银行，你们觉得会是谁？\\n\\n#bankofamerica'", nan), nan)
# (("'New Impact For Responsible Investing https://t.co/2F4CANeBit #arbitrage #assetmanagement #bankofamerica #blackrock #bridgewaterassociates #carlylegroup #esg #kkr'", nan), nan)
# (("'#PlaneAlert ICAO: #A89442 Tail: #N652BA \\nOwner: #BankofAmerica\\nAircraft: #Gulfstream G650 ER\\n2022/04/09 19:43:20\\n#GLF6 #Aaaaaaaanditsgone #BunchofBankers #ScroogeMcDuck https://t.co/cUszuYpU7l \\nhttps://t.co/CwJEdY4Mio https://t.co/LrY36tSuDq'", nan), nan)
# (("'#Bank of America: #Crypto Can Outperform Stocks Amid Potential Fed-Propelled Recession    #bankofamerica https://t.co/lzURiUIaFo'", nan), nan)
# (("'Opened up my bank account again! Thank you again @WellsFargo ! Best bank ever!\\nSoooo much better than  @BankofAmerica 👎🏼\\n#WellsFargo #assets #bankofamerica #Bitcoin #business #MONEY #MonthofGood #realestate #realtor #Twitter'", nan), nan)
# (("'El panorama macroeconómico de EEUU se está deteriorando rápidamente y podría empujar la economía a una recesión mientras la Reserva Federal endurece su política monetaria para controlar la creciente inflación. #Bankofamerica #joebiden https://t.co/dtqXFlGs6Q'", nan), nan)
# (("'Catch “Shrek the Musical” this weekend. You’ll be ogre-whelmed with laughter! \\n\\n#ShrektheMusical #Shrek #ChildrensTheatre #BankofAmerica #InfusionFund https://t.co/yzrLcwvgiL'", nan), nan)
# (("'Who got a #Truist account? Tap in 🤣🤣\\n#beatsforrappers #bankaccount #bankofamerica https://t.co/F5xE9xzdzY'", nan), nan)
# (("'“Iron Mike” Tyson &amp; Bank of America (BoA) Back Solana (SOL) | by Stephen Dalton | B.O.S.S. |Medium - via @pensignal  https://t.co/mrQVafD47O $SOL #Solana #BankofAmerica #MikeTyson @MikeTyson #cryptocurrencies  #writingservices #writerscommunity #medium #writerslift #SEO #Blogging'", nan), nan)
# (("#BankofAmerica Warns of 'Recession Shock,' But Will #Crypto Outperform? https://t.co/igQgbAIsOa", nan), nan)
# (("'فيسبوك و ميكروسوفت و أبل و ديسني و هولو و بنك اوف أميركا جميعهم يوظفون وظائف في العملات الرقمية وتكنولوجيا البلوك تشاين في الوقت الحالي.\\n\\n#Facebook #Apple #BankofAmerica #Hulu #Microsoft #Disney #Bitcoin #Crypto #Hodlfoundation'", nan), nan)
# (("'Yeni videomuz yayında arkadaşlar. Önemli açıklamaların yanında önemli analizler de bulunuyor. Aşağıdan ulaşabilirsiniz. #Bitcoin #DXY #BankofAmerica\\n\\nİyi seyirler...\\n\\nhttps://t.co/IQJaMUt7CF'", nan), nan)
# (("#BankofAmerica analyst warns clients that a '#recession shock' is on the horizon - days after #DeutscheBank forecasted an #economic downturn for 2023 due to Federal Reserve attempts to tame surging #inflation https://t.co/Q0e6prPKGW", nan), nan)
# (("'Recession Shock' Is Coming; Bank Of America Strategists Say Crypto Could Outperform Bonds\\xa0 \\xa0 - NRI Vision \\n#bankofamerica \\nhttps://t.co/p7ZPdETb2e", nan), nan)
# (("'$BAC enters bearish trend #BankofAmerica #stockmarket #stock https://t.co/KB0oKcDk3n'", nan), nan)
# (("$BAC's in Downtrend: Moving Average Convergence Divergence (MACD) Histogram crosses below signal line. View odds for this and other indicators: https://t.co/XUMafznokY #BankofAmerica #stockmarket #stock https://t.co/uaQFJT79vL", nan), nan)
# (('\'Bank Of America Says: "PREPARE FOR INFLATION SHOCK." Also A REAL THREAT ... https://t.co/aJn4N5VEwR via @YouTube #inflation #bankofamerica #Budget2022 #EconomicCrisis #bankrun\'', nan), nan)
# (("'#bankofamerica  Warns of ‘Recession Shock", "’ But Will #Crypto Perform Better?\\nhttps://t.co/2gRq3LvCxL'"), nan)
# (("'If ONE of your company employee makes me feel these type of way 😠😪😔😢😭😤😞☹😕😷😡😨🤕🤒", " The whole company will be judged.\\n\\nPLEASE ENLIGHTEN ME\\nWHY SHOULD I KEEP GIVING YOU LIFE aka LIGHT aka POWER aka MONEY?\\n\\nTreat Me Like A King Your GOD\\n#bankofamerica\\n#discoverycard'"), nan)
# (("'#News #50basispoints #BankofAmerica #Bitcoin #Bofa Bank of America Strategist Warns ‘Recession Shock’ Is Coming", " Analyst Says Crypto Could Outperform Bonds https://t.co/GyTAwotySh - https://t.co/HzksZFXjrd https://t.co/IcVaS5Tkms'"), nan)
# (("'#News #50basispoints #BankofAmerica #Bitcoin #Bofa Bank of America Strategist Warns ‘Recession Shock’ Is Coming", " Analyst Says Crypto Could Outperform Bonds https://t.co/b7seASPTEN Buy BTC: https://t.co/pNIc25EvfT https://t.co/2J7PfbVOiX'"), nan)
# (("'Bank of America advierte que se aproxima un «shock de recesión» #BankOfAmerica #EstadosUnidos #RecesiónEconómica #trending via @bitfinanzas https://t.co/yCpbudbMTM'", nan), nan)
# (("🏦#BankOfAmerica su #Bitcoin e #Crypto !\\n\\n📉La crisi sta per iniziare e sarà un'occasione per le #criptovalute !🔥\\n\\n✍Leggi l 'analisi su https://t.co/f4RDVoE1Na™️\\n\\nhttps://t.co/9k6Jc4rt8C\\n\\n#btc $BTC https://t.co/dj7kJheDAp", nan), nan)
# (("'Committed to Building our Communities addressing #workforcedevelopment #bankofamerica https://t.co/b3hgcp1XMx'", nan), nan)
# (("'#Options Flow Grid Update $BAC #OptionsTrading #bankofamerica Shares ⬆️1% to $39.81 #OptionsFlow #BoA #financialservices #Financial #stocks #stock #StockMarket #investing #Investment https://t.co/B7BWRcVOEf https://t.co/xLLi50WuRA'", nan), nan)
# (("'2022-04-08 12:50 PM\\n$BAC #BankofAmerica up 1.42% = $4.72 billion gain.\\n\\nhttps://t.co/hdeyqZ3gM7\\n(Apr 07) Consumers Keep On Spending: Analyzing Bank Of America Card Data And Costco Sales https://t.co/wjLwOpRXBw'", nan), nan)
# (("'Bank of America stopped playing and answer the phone my job showed me they paid me. Why isn’t it showing in my account. Answer the damn phone. #bankofamerica #bank'", nan), nan)
# (("'Bank of America prevê nova alta de juros em junho e Selic em 13", "25% https://t.co/eWuMmaiPe6 #BankOfAmerica #IPCA #Selic https://t.co/C6V0DQg1XW'"), nan)
# (("'#bankofamerica waiting in line", ' all services reduced'), " floating teller. Maybe change banks'")
# (("#MCIA added the $60.5M #BankofAmerica Center loan to the #Morningstar Watchlist after the property's net cash flow tumbled to $4.8M in 2021 down from $6.2M in 2020. Read our #CMBS Chronicle to learn more: https://t.co/wL9c0RRkDR #CreditRatings #CRE #BofA #RealEstate https://t.co/KA2r2A2HOl", nan), nan)
# ...
# (("'@jarpad Thales Group (French pronunciation: [talɛs]) is a French multinational company that designs and builds electrical systems and provides services for the aerospace", ' defence'), " transportation and security markets.\\n\\n#Airbus I was shown; No wrong #BankofAmerica \\n\\nhttps://t.co/yl8wTpt8Ne'")
# (("'mailleri açmayın diyerek uyardı bende tamamen işkillendim ve googleden aratma yaptım (#BankOfAmerica) diye araştırma yaptım biraz ve bakınırken #şikayetvar dan bildirimleri gördüm girdim ve bana yaptıgının aynısını onlarada yapmış kuzenime göndericem falan filan diyerek onlar'", nan), nan)
# (("'Bank of America now says the crypto metaverse is a ‘massive opportunity’ https://t.co/bff8I6MkwA #Banking #Metaverse #NFTs #BankofAmerica #Grayscale'", nan), nan)
# (("'#Banking #Metaverse #NFTs #BankofAmerica #Grayscale Bank of America now says the crypto metaverse is a ‘massive opportunity’ https://t.co/3ffIJ2Yk68 - https://t.co/HzksZFXjrd https://t.co/M5Vwa96Qdf'", nan), nan)
# (("'Stratejistlerin 2022 Yili Icin SP500 Hedef Seviyeleri \\n\\n#bloomberg #stratejist #sp500 #borsa #endeks #abd #analiz #bankofamerica #barclays #citigroup https://t.co/MZFfeHzv7W'", nan), nan)
# (("'#miatk ne oldu lan paşinyan:))) 10. Tavan hala pesinizdeyiz kaçamazsın #bankofamerica #a1 https://t.co/EdORiM0Hwe'", nan), nan)
# (("'@hitRECordJoe Taking note of 500MB (2015) 4K file nothing cause 100x or 50x &amp; like🇨🇳 a woman or women can do be whatever 🙄 men only males tend be bothered by hanger on online especially in technological #BankofAmerica electronics regardless of a car 🚗 stereo whatever.\\nhttps://t.co/GBbUxodL6U'", nan), nan)
# (("'#bankofamerica believes on #Metaverse https://t.co/Gg8Bx94hft'", nan), nan)
# (("'$BAC in Downtrend: RSI indicator exits overbought zone. View odds for this and other indicators: https://t.co/Gh0DlaoTsN #BankofAmerica #stockmarket #stock https://t.co/pXRweDDxtU'", nan), nan)
# (("'#BoA $X #bankofamerica #Dallas #TX #NEONCITYBANDITS #YUUUGE'", nan), nan)
# (("'#PodsumowanieDnia: wtorek (2 grudnia):\\n\\n✅ Chociaż #BTC nie osiągnął ceny 98 000 USD", " #PlanB nie odrzuca modelu #S2F\\n✅ #Putin postrzega aktywa cyfrowe jako ryzykowne inwestycje\\n✅ #BankofAmerica: #Metaverse szansą dla #krypto\\n✅ #SnoopDogg w #metaversum\\n\\nCoś przegapiliśmy? 🤔'"), nan)
# (("'Just retweeting this and leaving this here:\\n\\nIt’s no secret what $XRP is about to become‼️‼️\\n-\\nLet’s stop acting blind.\\n-\\n#XRPL #XRP #RIPPLE $RIPPLE #CRYPTO #BTC #ETH $BTC $ETH $XRP #JPMORGAN $BOA #BankofAmerica https://t.co/Avd37PKQs2 https://t.co/NUq0bCv5in'", nan), nan)
# (("'✨ In case you missed it  👀", " check out our latest impact story in @SFBusinessTimes highlighting the immense potential of our Geniuses and the tremendous growth of our organization. 🙌🏿 \\n\\nhttps://t.co/6qj3dW4EK6 \\n\\n#BlackYouth #BankofAmerica #TheHiddenGeniusProject'"), nan)
# (("'Bank of America is sticking to its $85-a-barrel forecast.\\n\\n#BankofAmerica #omicron  #trajectory #OOTT\\n\\nhttps://t.co/yo8TZWF3Ks'", nan), nan)
# (("'Metaverso é uma grande oportunidade para as criptomoedas", " afirma Bank of America - https://t.co/QsQAPvAL1J \\n#MundoCrypto #Metaverse  #bankofamerica #crypto #CryptoNews'"), nan)
# (("'Metaverso é uma grande oportunidade para as criptomoedas", " afirma Bank of America - https://t.co/g0BmSiCCis \\n\\n#criptomoedas #BofA #BankofAmerica'"), nan)
# (("'Bank of America strategist says metaverse is a massive opportunity for crypto #bankofamerica #haimisrael #strategist https://t.co/zFOwHL0ls0'", nan), nan)
# (("'#Technology #BankofAmerica Bank of America strategist says metaverse is a massive opportunity for crypto https://t.co/1TAKI6FPGb'", nan), nan)
# (("'@BankofAmerica Do @BankofAmerica need help to start recover their shorts before AMC squeeze? Now its the time...\\n\\n#bankofamerica \\n#AMC https://t.co/B1XcgImYct'", nan), nan)
# (("'#Cryptocurrency #BankofAmerica #Crypto #Market #Trading Bank of America says the metaverse is an opportunity for the crypto sector https://t.co/PmBVB38CPV - https://t.co/HzksZFXjrd https://t.co/hOqZXqpMtk'", nan), nan)
# (("'Bank of America says the metaverse is an opportunity for the crypto sector https://t.co/LJn0QEWt5a #Cryptocurrency #BankofAmerica #Crypto #Market'", nan), nan)
# (("'NEW Blog Article: The CBD Industry Has a Lying to Banks Problem— Which Some People Pay for in Jail Time https://t.co/ZZsaXI86qE #cbd #cams #aml #banking #bankofamerica #chase #square #compliance #fdic #fincen #ftc #doj https://t.co/7IsETmkn1w'", nan), nan)
# (("'Bank Of America: #Metaverse", " kripto ve bunun benimsenmesi için büyük bir fırsat.\\n\\n#bankofamerica'"), nan)
# (('\'#BankofAmerica: "#Metaverse', ' #kripto\\\'nun benimsenmesi için büyük bir fırsat."\''), nan)
# (("'CA / CMA vacancy in Bank of America\\n\\n#CA  #CMA #BankofAmerica \\n\\nRead More: https://t.co/mcxgZXuFO8'", nan), nan)
# (("'CA / CMA vacancy in Bank of America\\n\\n#CA  #CMA #BankofAmerica \\nRead More: https://t.co/LTuHMICqyz'", nan), nan)
# (("'Bank of America:   #Metaverse", " kriptonun benimsenmesi için büyük bir fırsat.\\n\\n#kripto #kriptopara #dolar #BankOfAmerica #Metaverses https://t.co/Ds7569ihRC'"), nan)
# (("'Bank of America vê uma grande oportunidade no metaverso\\n\\n📌PARA LER O ARTIGO COMPLETO", " ACESSE O LINK\\n\\n#Bitcoin #BTC #unibtc #crypto #criptomoedas #BankOfAmerica #Metaverso #Facebook #MorganStanley \\n\\nhttps://t.co/dsiVw5G1sC'"), nan)
# (("'#bankofamerica'", nan), nan)
# (("'The #metaverse is a massive opportunity for crypto that calls for new platforms and tokens", " #BankofAmerica strategist says -  https://t.co/uJ1VjV5Fgp #CryptocurrencyNews https://t.co/5nbVD4B7IM'"), nan)
# (('\'"I definitely believe this is a massive', ' massive opportunity. The metaverse is where we\\\'re going to start using cryptocurrencies as currencies." #bankofamerica #metaverse #cryptocurrencies\\nhttps://t.co/HzxQOhCQp1\''), nan)
# (("'#BankOfAmerica: #Metaverse", " kriptonun benimsenmesi için büyük bir fırsat.'"), nan)
# (("'#BankofAmerica: #Metaverso", " una gran oportunidad para el #blokchain https://t.co/SmRxMjzcnF a través de @EstrategiasTv'"), nan)
# (("'Bank of America: Metaverso", " una gran oportunidad para el blokchain #Metaverso #BankOfAmerica #Blockchain #Bitcoin #Ethereum #Criptomonedas\\nhttps://t.co/lrekDgIK7T'"), nan)
# (("'Managing #Director  of #research  at #BankofAmerica #HaimIsrael", " assumes #Metaverse  will boost the #Crypto  industry.\\n\\n#blockchain #Virtual #cryptocurrencies \\n\\nhttps://t.co/KJbS4AD7TP'"), nan)
# (("'News: Bank Of America Sees A Lot Of Potential In The Metaverse\\n\\nThe metaverse", ' according to Bank of America strategist Haim Israel'), " represents a big…\\n\\nRead More: https://t.co/ZyiKJPhdAF\\n\\n#BankOfAmerica #Metaverse #Cryptocurrency #coinscapture #CryptoNews https://t.co/vocz10rtYh'")
# (("'Metaverse dan kripto", " disebut oleh Analis Haim Israel dari Bank of America (BoA) merupakan perpaduan yang baik. \\n\\nhttps://t.co/L9KCw82WMz\\n\\n#metaverse #BankofAmerica #aset #virtual #kripto #crypto #blockchain #money #uang #investasi'"), nan)
# (("'Banco da América: O Metaverso é uma Enorme Oportunidade para a Indústria de Criptomoedas https://t.co/zAMLXrFCxp via @BitcoinAngola #btc #BankOfAmerica'", nan), nan)
# (("@BankofAmerica: Metaverse, Kripto Para Endüstrisi İçin Muazzam Bir Fırsat!\\n @BankofAmerica'da bir stratejist olan #HaimIsrael, #metaverse'in blockchain teknolojisi için büyük fırsatlar yaratacağına inanıyor! \\n\\n#metaverse #bankofamerica #blockchain #kripto #PlayToEarn  #GameFi", nan), nan)
# (("'#BTC\\n#BankofAmerica \\n#Metaverse https://t.co/WkdTXSJQeH'", nan), nan)
# (("'Mission Vibrant: CM ભૂપેન્દ્ર પટેલની બેંક ઓફ અમેરિકાના પ્રેસિડન્ટ સાથે બેઠક", " આ મહત્વના મુદ્દાઓ પર થઇ વાત\\n\\n#CMBhupendraPatel #Bankofamerica #KakuNakhate\\n\\nhttps://t.co/nKm6WL3yyw'"), nan)
# (("'Today i do super early update to hedgies and bank with shorts down. (05.57am here) \\n\\n@citsecurities @BankofAmerica \\n@GoldmanSachs @BMO @RBC \\n\\n#StillHereKenny \\n#CitadelIsNotRetail \\n#CitadelScandal \\n#citadel \\n#bankofamerica \\n#goldmansachs \\n#FailToDeliever \\n#AMCtothemoon \\n#FTD https://t.co/OYUZwHP9jH'", nan), nan)
# (("#BankofAmerica's expert says #Metaverse is future of crypto - Bitcoinik https://t.co/h4U1NaBSLt", nan), nan)
# (("'Bank of America Sees Massive Opportunity in Metaverse for Entire Crypto Ecosystem – Metaverse Bitcoin News\\nhttps://t.co/nf6PePZ0zo\\n\\n#digitalcurrency #cryptocurrency #metaverse #bankofamerica #technology'", nan), nan)
# (("'Bank of America’s Strategist Says the Metaverse is a Massive Opportunity for Blockchain Technology\\nhttps://t.co/aV21ZR5Nz2\\n#BankofAmerica #Metaverse #Blockchain #Technology #Crypto #stablecoins https://t.co/REj5CAixy2'", nan), nan)
# (('\'#Crypto #cryptocurrency #คริปโต #คริปโตเคอเรนซี #Metaverse #BankofAmerica\\n\\n"Metaverse" Is a Massive Opportunity for "The Crypto Industry" 😋👍💵🎉\'', nan), nan)
# (("$BAC's price moved below its 50-day Moving Average on November 30, 2021. View odds for this and other indicators: https://t.co/8s4kaDesiP #BankofAmerica #stockmarket #stock https://t.co/ZEmHijeHP2", nan), nan)
# (("Metaverse is a 'Massive, Massive Opportunity' for Crypto – BofA Strategist https://t.co/5CcnZzFfJU #AltcoinNews #Metaverse #BankofAmerica #Stablecoin #DeFi", nan), nan)
# (("#AltcoinNews #Metaverse #BankofAmerica #Stablecoin #DeFi Metaverse is a 'Massive, Massive Opportunity' for Crypto – BofA Strategist https://t.co/n1o7YRAzhQ - https://t.co/HzksZFXjrd https://t.co/4PnBcJPuiQ", nan), nan)
# (("'Primer caso de variante omicron en Estados Unidos\\nhttps://t.co/1LI6az7ooz\\n#Pujols", ' #KenyaRomero'), ' #Linares')
# (("'@BankofAmerica Really sad that you can’t staff your branches. I’m being sent to the UPS store for notary. Thank you for valuing me as a customer. ☹️☹️☹️ #LasVegas #BankofAmerica https://t.co/906ooQ4k4D'", nan), nan)
# (("'The Power of Bitcoin 💥🔥\\n•\\nLearn &amp; Invest with Fint money.\\n\\n#jpmorgan #boa #bankofamerica #wellsfargo #bitcoin #btc #marketcap #holding #staking #farming #banks #usa https://t.co/U2t5yxCbvQ'", nan), nan)
# (("'Alternative meat company #GreenMonday Holdings in Hong Kong is seeking about $100 million in new capital", " as the plant-based protein company is working with #BankofAmerica in its latest funding round. https://t.co/6fs9yRvrkY'"), nan)
# (("@BrianWestbrook @travelcodex @AlaskaAir OK I'm (easily) confused. I thought the spend-your-way-to-MVP/GOLD promo ended Nov. 15. Was it continued? Hey--I'm doing my part, along w #Costco #BankOfAmerica etc. @alaskaair", nan), nan)
# (("'تسعى شركة اللحوم البديلة #GreenMonday Holdings في هونغ كونغ، إلى جمع حوالي 100 مليون دولار من رأس المال الجديد، حيث تعمل شركة البروتين النباتي مع #BankofAmerica في جولة التمويل الأخيرة. https://t.co/GZJ5MQnSbV'", nan), nan)
# (("'Thanks to @BankofAmerica and Alkesh Shah for the great live-streaming - Leveraged Finance Conference.\\n\\n#bankofamerica #7ccblockchaininvestments #criptocurrency #blockchain #securitytokens https://t.co/Kg7BoS0Gkx'", nan), nan)
# (("'#Bankofamerica When signing online why is it forcing me to get paperless statements? I am not able to opt out and unable to move further within my account.'", nan), nan)
# (("'Das #Metaverse wird letztendlich dafür sorgen", ' dass #Kryptowährungen als Währungen in der virtuellen Welt verwendet werden'), " so ein Stratege der Bank of America über das Potenzial der schnell wachsenden #Krypto-Nische. https://t.co/tIS6Fm5Elf #bankofamerica'")
# (("'Bank of America opina que la trayectoria macroeconómica de RD es la más prometedora de América Latina para los próximos años", " y estima ser el segundo país con mayor crecimiento económico de la región \\n\\n#elCaribe #BankofAmerica #trayectoria #positiva https://t.co/z8hgGdgm5Q'"), nan)
# (("'RD tiene trayectoria macroeconómica más prometedora de América Latina", " según @BankofAmerica \\n\\nConozca más detalles aqui:\\n https://t.co/YMCPC9yWV8\\n\\n#Económicas #BankofAmerica #RD #Noticias22'"), nan)
# (("'A.I.dvisor made a bearish call on $BAC", " netting in a 3.99% gain over 1 week #BankofAmerica #stockmarket #stock https://t.co/1sZD53ROjU https://t.co/5tKSJUKumX'"), nan)
# (("'Look up those with #iota in their patents like $boa (#bankofamerica or #Gemini etc'", nan), nan)
# (("'@usbank You guys have an eye catching logo.  Do you guys have banking fess like #BankofAmerica they are making  $144.00 US dollars a year off of me.'", nan), nan)
# (("'BOA has gotten me out of 2 awkward situations with men &amp; I love them for that. 😩🙌🏾\\n\\n#bankofamerica'", nan), nan)
# (("'@JadeFranco7 @Hertz Thanks @JadeFranco7 this is where it gets worse. @Hertz lied to @BankofAmerica and #BankOfAmerica simply took them at their word", " even though I explained it was a contactless return due to covid and Hertz erroneously recorded it the following day. What do I even do now? https://t.co/0qi0Mp3TUk'"), nan)

# %%
import wordcloud
from nltk.corpus import stopwords
import nltk
import string
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
stop = stopwords.words('english')
df['stopwords'] = df['content'].apply(lambda x: len([x for x in str(x).split() if x in stop]))
# df[['content','stopwords']].head()
# Out:
# [nltk_data] Downloading package stopwords to /Users/gaode/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/gaode/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/gaode/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/gaode/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
df['content'] = df['content'].apply(lambda x: " ".join(x.lower() for x in str(x).split()))
# df['content'].head()

# %%
df['content'] = df['content'].str.replace('[^\w\s]','')
# df['content'].head()
# Out:
# /var/folders/1f/snwvkg952g599fptk4bdqm3r0000gn/T/ipykernel_90745/2232345864.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['content'] = df['content'].str.replace('[^\w\s]','')

# %%
df['content'] = df['content'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
# df['content'].sample(10)

# %%
def remove_url(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', text)
import re
import string

df['content'] = df['content'].apply(lambda x: remove_url(x))

# %%
def remove_html(text):
    html=re.compile(r'<.*?>')
    return html.sub(r'',text)
df['content'] = df['content'].apply(lambda x: remove_html(x))

# %%
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags 
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)
# remove all emojis from df
df['content'] = df['content'].apply(lambda x: remove_emoji(x))

# %%
import re
import string

def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    return text

round1 = lambda x: clean_text_round1(x)
df['content'] = df.content.apply(round1)

# %%
def clean_text_round2(text):
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

round2 = lambda x: clean_text_round2(x)
df['content'] = df.content.apply(round2)
# df.content

# %%
w = wordcloud.WordCloud(background_color="white")  

def newsfunction(a):
    res = str()
    for i in a:
        res +=','
        res += i
    return ''.join(res)

freq = pd.Series(' '.join(df['content']).split()).value_counts()[:50]
new_data = pd.DataFrame(freq)
new_data['keywords'] = freq.index
abc = newsfunction(new_data['keywords'])
w.generate(abc)
w.to_file("pywordcloud2.png")

# %%
#TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer
STOPWORDS = stopwords.words('english')
vect = TfidfVectorizer(stop_words=STOPWORDS,max_features=2000)
vect_text = vect.fit_transform(df['content'])

# %%
#LDA
from sklearn.decomposition import LatentDirichletAllocation
lda_model=LatentDirichletAllocation(n_components=30,
learning_method='online',random_state=100,max_iter=20) 
lda_top=lda_model.fit_transform(vect_text)

# %%
def maxi(x):
    maximum = x[0]
    for i in range (0,len(x)):
        if x[i] >= maximum:
            maximum = x[i]
            index=i
    return index

# %%
#find top 10 words in each topic
vocab = vect.get_feature_names()
topics=[]
for i, comp in enumerate(lda_model.components_):
     vocab_comp = zip(vocab, comp)
     sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
     c, v =  zip(*sorted_words)
     topics.append(c)
#      print(" ")
#      print("Topic "+str(i)+": ")
#      for t in sorted_words:
# #             topics[i].append(t[0])
#             print(t[0],end=" ")
#      print("\n")

# %%
#find the index of the topic list of each tweet.
topic_index=[]
for i,topic in enumerate(lda_top):
#     print("tweet ",i,": ",maxi(topic))
    topic_index.append(maxi(topic))

# %%
df['topic_index'] = topic_index

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report

X=df['content'].values
y=df['topic_index'].values.reshape(-1,1)

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Random Forest for tweets
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators=123,random_state=18,max_depth=300)
forest.fit(X_train,y_train)
y_pred_forest = forest.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_forest))
# Out:
# /var/folders/1f/snwvkg952g599fptk4bdqm3r0000gn/T/ipykernel_90745/3929655047.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(X_train,y_train)
# Accuracy: 0.9277777777777778

# %%
from pygooglenews import GoogleNews
import newspaper

gn = GoogleNews()
newsArticles = gn.search("bank of america")
newsArticles = newsArticles['entries']
articles = []
for entry in newsArticles:
    url = entry['link']
    article = newspaper.Article(url=url, language='en')
    article.download()
    try:
        article.parse();
        if str(article.title)=="Are you a robot?":
            continue
        if str(article.text)=="":
            continue
        article = {
            "title": str(article.title),
            "text": str(article.text),
            "authors": article.authors,
            "published_date": str(article.publish_date),
            "top_image": str(article.top_image),
            "videos": article.movies,
            "keywords": article.keywords,
            "summary": str(article.summary)
        }
        #print("----------"+article["title"] + "------:" + article["text"] + "\n\n")
        articles.append(article);
    except: #if url can not be parsed by parser go to next entry
        continue

# %%
vect = TfidfVectorizer(stop_words=STOPWORDS,max_features=2000)
vect_text = vect.fit_transform(dfa['text'])

lda_model=LatentDirichletAllocation(n_components=10,
learning_method='online',random_state=100,max_iter=20) 
lda_top=lda_model.fit_transform(vect_text)

# %%
#find top 10 words in each topic
vocab = vect.get_feature_names()
topics=[]
for i, comp in enumerate(lda_model.components_):
     vocab_comp = zip(vocab, comp)
     sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:5]
     c, v =  zip(*sorted_words)
     topics.append(c)
#      print(" ")
#      print("Topic "+str(i)+": ")
#      for t in sorted_words:
# #             topics[i].append(t[0])
#             print(t[0],end=" ")
#      print("\n")

# %%
#find the index of the topic list of each articel.
topic_index=[]
for i,topic in enumerate(lda_top):
#     print("article ",i,": ",maxi(topic))
    topic_index.append(maxi(topic))

# %%
dfa['topic_index'] = topic_index
X=dfa['text'].values
y=dfa['topic_index'].values.reshape(-1,1)

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(X)
# print(X.shape, y.shape)
# print(X[0][0])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
clf = MultinomialNB().fit(X_train, y_train)
predictions = clf.predict(X_test)
# predictions
# # print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predictions))  
# # print('Mean Squared Error:', metrics.mean_squared_error(y_test, predictions))  
# # print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# # print('R-squared Error:', metrics.r2_score(y_test, predictions))
# Out:
# /Users/gaode/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
# print("Test set score: {:.2f}".format(np.mean(y_pred == y_test)))
train_accuracy = clf.score(X_train, y_train)

# %%
#Random Forest for Articles
forest = RandomForestClassifier(n_estimators=123,random_state=18,max_depth=300)
forest.fit(X_train,y_train)
y_pred_forest = forest.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_forest))
# Out:
# Accuracy: 0.8235294117647058
# /var/folders/1f/snwvkg952g599fptk4bdqm3r0000gn/T/ipykernel_90745/3890746267.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(X_train,y_train)
